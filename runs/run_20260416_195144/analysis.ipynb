# %% [markdown]
# # Analisis de entrenamiento Tiny ImageNet
#
# Notebook generado automaticamente.
#
# Metricas minimas:
# - epoch
# - cost
# - train
# - test
# - epoch_time
# - total_time

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
csv_file = Path(r"runs\run_20260416_195144\history.csv")
json_file = Path(r"runs\run_20260416_195144\summary.json")
df = pd.read_csv(csv_file)
with open(json_file, 'r', encoding='utf-8') as f:
    summary = json.load(f)
df

# %% [markdown]
# ## Resumen
#
# - Arquitectura: small_cnn
# - Optimizer: adam
# - Epochs: 50
# - Workers: 6
# - Local epochs: 1
# - LR: 0.01
# - Batch size train: 128
# - Batch size test: 256
# - Device: cpu
# - Mejor test: 0.3395
# - Mejor epoch: 39
# - Tiempo total: 6257.50 s

# %%
best_idx = df['test'].idxmax()
best_row = df.loc[best_idx]
print(f"Mejor epoch: {int(best_row['epoch'])}")
print(f"Cost: {best_row['cost']:.6f}")
print(f"Train: {best_row['train']:.6f}")
print(f"Test: {best_row['test']:.6f}")
print(f"Tiempo total final: {df.iloc[-1]['total_time']:.2f} s")

# %%
plt.figure(figsize=(8,5))
plt.plot(df['epoch'], df['cost'], marker='o')
plt.title('Cost por epoch')
plt.xlabel('Epoch')
plt.ylabel('Cost')
plt.grid(True)
plt.show()

plt.figure(figsize=(8,5))
plt.plot(df['epoch'], df['train'], marker='o', label='Train')
plt.plot(df['epoch'], df['test'], marker='s', label='Test')
plt.title('Accuracy por epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()

plt.figure(figsize=(8,5))
plt.plot(df['epoch'], df['epoch_time'], marker='o', label='Tiempo por epoch')
plt.plot(df['epoch'], df['total_time'], marker='s', label='Tiempo acumulado')
plt.title('Tiempo de entrenamiento')
plt.xlabel('Epoch')
plt.ylabel('Segundos')
plt.grid(True)
plt.legend()
plt.show()
